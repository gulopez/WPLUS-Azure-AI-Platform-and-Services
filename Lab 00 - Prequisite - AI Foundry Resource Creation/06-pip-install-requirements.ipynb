# %%
#run pip install using requirements.txt file in the LABS root directory

# %%
from pathlib import Path

notebook_path = Path().absolute()
requirements_path = notebook_path.parent / 'requirements.txt'
#print(f"Notebook path: {notebook_path}")
print(f"Requirements path: {requirements_path}")
# Out:
# Requirements path: /workspaces/WPLUS-Azure-AI-Platform-and-Services/requirements.txt

# %%
# %pip install -r {requirements_path}
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
